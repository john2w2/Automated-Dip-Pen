# %%
import sys
sys.path.append("C:/Users/19199/Desktop/automated-sca/src")

# %%
from pressure import Pressure
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3702278df34e> in <module>
# ----> 1 from pressure import Pressure
#
# ModuleNotFoundError: No module named 'pressure'

# %%
ps = Pressure()

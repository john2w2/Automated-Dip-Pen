# %%
import sys
sys.path.append("C:/Users/19199/Desktop/automated-sca/src")

# %%
from pressure import Pressure

# %%
ps = Pressure()
# Out:
# Device connection made

# %%
ps.pcontroller.get_pressure(4)
# Out:
# 0.06359863276031774

# %%
ps.offset
# Out:
# 0.0

# %%
ps.recalibrateOffset()
# Out:
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.06359863276031774
# 0.00256347656033995
# 0.00256347656033995
# 0.00256347656033995
# 0.06359863276031774
# 0.00256347656033995
# 0.06359863276031774
# 0.06359863276031774
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.00256347656033995
# 0.00256347656033995
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.00256347656033995
# 0.06359863276031774
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.00256347656033995
# 0.06359863276031774
# 0.00256347656033995
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.06359863276031774
# 0.00256347656033995
# -0.05847167963963784
# 0.00256347656033995
# 0.06359863276031774
# 0.06359863276031774
# 0.00256347656033995
# 0.00256347656033995
# 0.00256347656033995
# 0.00256347656033995
# 0.06359863276031774
# 0.00256347656033995
# ...

# %%
# ps.pcontroller.set_pressure(4, ps.offset)
ps.pcontroller.set_pressure(4, ps.offset)
# Out:
# 0

# %%
ps.offset
# Out:
# -0.033081054660328846

# %%
ps.pcontroller.get_pressure(4)
# Out:
# 0.06359863276031774

# %%
ps.pcontroller.close()
# Out:
# 0

# %%
import sys
sys.path.append("C:/Users/19199/Desktop/automated-sca/src")

from stage import Stage
from plate import Plate
from chip import Chip
import serial

import calib

# %%
center = calib.calibFirstWellPos()

# %%
print(center)
# Out:
# (-3383252, -487060)

# %%
c = Chip()
p = Plate(2,3,40000) # roughly the diameter for 6-well plate, a little off
# p = Plate()
s = Stage(p, c)

# %%
s.setOrigin()

# %%
# s.moveToPos(-3401756, -477041)
# s.moveToPos(-3383326, -487051)
# New center, August 31, (-3383252, -487060)
s.moveToPos(center[0], center[1])

# %%
s.moveXInUM(10000)

# %%
s.moveYInUM(10000)

# %%
s.isRealChannel(41)
# Out:
# Channel number out of bounds!
# Currently using chip with 40 channels
# False

# %%
s.setFirstChannelCamPos()

# %%
s.firstChannelCamPos
# Out:
# (-2016268, -1409635)

# %%
s.moveToChannelCam(1)

# %%
s.moveToChannelCam(12)

# %%
s.moveToChannelCam(40)

# %%
s.getStageXY()
# Out:
# [-2016371, -1480951]

# %%
s.setOrigin()

# %%
s.getStageXY()
# Out:
# [2, 0]

# %%
s.setFirstWellPos()

# %%
s.moveToWell("1,1")

# %%
s.moveToWell("2,3")

# %%
s.moveToWell("8,1")
# Out:
# Row and/or column out of bounds!
# Currently using 6-well plate with dimensions: 2 rows, 3 columns

# %%
s.moveToWell("8,12")
# Out:
# (-2147477, -293671)
# -2475000.0 -1575000.0

# %%
s.firstWellPos
# Out:
# (-2410155, -562813)

# %%
s.close()

# %%
import sys
sys.path.append("C:/Users/19199/Desktop/automated-sca/src")

from stage import Stage
from plate import Plate
from chip import Chip
import serial

import calib

# %%
c = Chip()
p = Plate()
# p = Plate(2,3,40000) # roughly the diameter for 6-well plate, a little off
ser = serial.Serial(port="COM6", baudrate=9600, timeout=0.1)
s = Stage(p, c, ser)

# %%
# First move using joystick to origin
# Then click this
s.calibOrigin()

# %%
s.moveToOrigin()

# %%
# Next get the offset (estimate)
# Move camera to first channel
a = s.getStageXY()

# %%
# Then move printer to first channe;
b = s.getStageXY()

# %%
s.calibPrinterOffset(b[0]-a[0], b[1]-a[1])

# %%
s.printerOffset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\19199\Desktop\automated-sca\testing\testStage.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19199/Desktop/automated-sca/testing/testStage.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> s.printerOffset
#
# AttributeError: 'Stage' object has no attribute 'printerOffset'

# %%
# Now move first channel under camera
s.calibFirstChannelCamPos()

# %%
# Move first well under camera
s.calibFirstWellCamPos(s.getStageXY())

# %%
s.moveChannelToCam(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\19199\Desktop\automated-sca\testing\testStage.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19199/Desktop/automated-sca/testing/testStage.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> s.moveChannelToCam(1)
#
# File C:\Users/19199/Desktop/automated-sca/src\stage.py:168, in Stage.moveChannelToCam(self, chanNum)
#     166 if self.isRealChannel(chanNum=chanNum):
#     167     yOffset = (chanNum - 1) * self.chanStepSize * -1
# --> 168     cmd = f"G,{self.firstChannelCamPos[0]},{self.firstChannelCamPos[1]+yOffset}"
#     169     self.writeRead(cmd, isMoveCmd=True)
#
# AttributeError: 'Stage' object has no attribute 'firstChannelCamPos'

# %%
s.moveChannelToPrinter(40)

# %%
s.moveWellToPrinter("5, 3")

# %%
s.close()

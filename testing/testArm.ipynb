# %%
import sys
sys.path.append("C:/Users/19199/Desktop/automated-sca/src")

from stepper import *
from arm import *

# %%
sc = Screw()
st = Stepper(sc)
zm = ZMotor(st)

# %%
zm.calibrateOrigin()

# %%
zm.moveToZInUM(0)

# %%
zm.moveToZRelInMM(-20)

# %%
zm.getZPosInUM()
# Out:
# -19987.846153846156

# %%
zm.moveToZRelInUM(-20000) # 2 cm down

# %%
zm.moveToZInUM(-6 * 10000)   # -x cm

# %%
zm.moveToZRelInUM(-2000) # 2 mm down

# %%
zm.getZPosInUM()
# Out:
# -19987.846153846156

# %%
zm.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\19199\Desktop\automated-sca\src\test2.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19199/Desktop/automated-sca/src/test2.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> zm.close()
#
# NameError: name 'zm' is not defined

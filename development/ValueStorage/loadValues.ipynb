# %%
import os
import pathlib

# %%
print(__file__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\19199\Desktop\automated-sca\testing\loadValues.ipynb Cell 2 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19199/Desktop/automated-sca/testing/loadValues.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> print(__file__)
#
# NameError: name '__file__' is not defined

# %%
import sys
sys.path.append("C:/Users/19199/Desktop/automated-sca/src")

from orcaFlash import OrcaFlashV2

# %%
import numpy as np
from PIL import Image
from utils.camera_utils import apply_gain
import datetime
from utils.camera_utils import get_date_str
from utils.camera_utils import save_image_from_camera

# %%
cam = OrcaFlashV2()

# %%
cam.connect()
# Out:
# 2022-12-01 16:39:19.664 | INFO     | pymmcore_plus.core._mmcore_plus:setDeviceAdapterSearchPaths:152 - setting adapter search paths: ['C:\\Program Files\\Micro-Manager-2.0']

# %%
cam.start_acquisition()

# %%
cam.stop_acquisition()

# %%
im = cam.get_next_frame()

# %%
im
# Out:
# array([[116, 111, 113, ..., 114, 130, 123],
#        [114, 120, 106, ..., 110, 108, 135],
#        [113, 117, 120, ..., 121, 113, 119],
#        ...,
#        [116, 112, 115, ..., 120, 119, 111],
#        [116, 107, 128, ..., 140, 138, 115],
#        [117, 112, 107, ..., 119, 117, 126]], dtype=uint16)

# %%
im.shape
# Out:
# (2048, 2048)

# %%
apply_gain(im, 200)

# %%
pilim = Image.fromarray(im)

# %%
pilim.show()

# %%
get_date_str(True)
# Out:
# '2022_12_01\\16_39_23'

# %%
cam.start_acquisition()

# %%
save_image_from_camera(camera=cam, gain=100)

# %%
cam.stop_acquisition()

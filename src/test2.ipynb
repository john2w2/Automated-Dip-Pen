# %%
from stepper import *
from arm import *

# %%
sc = Screw()
st = Stepper(sc)
zm = ZMotor(st)

# %%
zm.calibrateOrigin()

# %%
zm.moveToZAbsolute(-1000)

# %%
zm.getZPosition()
# Out:
# -1000

# %%
zm.close()

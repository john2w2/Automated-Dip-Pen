# %%
from stage import Stage
from plate import Plate
from chip import Chip
import serial

c = Chip()
p = Plate()
s = Stage(p, c)

# %%
s.writeRead("G,0,0")
# Out:
# ''

# %%
s.setOrigin()
# sometimes prints Rb R
# sometimes prints:  b 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\19199\Desktop\automated-sca\src\test.ipynb Cell 3 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19199/Desktop/automated-sca/src/test.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> s.setOrigin()
#
# File c:\Users\19199\Desktop\automated-sca\src\stage.py:29, in Stage.setOrigin(self)
#      25 def setOrigin(self):
#      26     # TODO: make a note of this in the official docs
#      27     # Since (0, 0) is bottom right, stage up => y decreases, stage left => x decreases
# ---> 29     self.writeRead("G,0,0", isMoveCmd=True) # Move stage to absolute 0,0 position
#      30     self.writeRead("P,0,0,0")
#
# File c:\Users\19199\Desktop\automated-sca\src\stage.py:87, in Stage.writeRead(self, cmd, isMoveCmd)
#      85 res = self.ser.readline()
#      86 while(not(b'W' in res)):
# ...

# %%
s.getStageXY()
# Out:
# [-465345, -677857]

# %%
s.setFirstWellPos()

# %%
s.firstWellPos
# Out:
# (-653498, -306750)

# %%
s.close()

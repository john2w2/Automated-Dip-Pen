# %%
from stage import Stage
from plate import Plate
from chip import Chip

# %%
c = Chip()
p = Plate()
s = Stage(p, c)

# %%
s.write("SIS")

# %%
s.write("G,0,0")
# test this tmrw, weird thing happened where we did not go to 0, x stayed still

# %%
res = s.writeRead("G,-2000000,-300000")
print(res)
# Out:
# 0

# %%
s.write("P,0,0,0")

# %%
s.close()

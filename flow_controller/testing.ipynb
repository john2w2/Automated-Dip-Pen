# %% [markdown]
# note: no automatic creation of calibration file

# %% [markdown]
# # TO trigger waveform voltage box: TTL,0,1 then sleep then TTL,0,0

# %% [markdown]
# testing with printer head should make volumes more consistent

# %%
from OB1 import *
from time import sleep

# %%
ob = OB1(calibrate=False)
# Time: 3m 31s
# Out:
# Device connection made

# %%
ob.get_pressure(4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\19199\Desktop\automated-sca\flow_controller\testing.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/19199/Desktop/automated-sca/flow_controller/testing.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> ob.get_pressure(4)
#
# NameError: name 'ob' is not defined

# %%
ob.set_pressure(channel=4, pressure= 3)
# Out:
# 0

# %%
stop()

# %%
def inThenHold():
    ob.set_pressure(4, -80)
    sleep(2)
    ob.set_pressure(4, 0)

# %%
def dispenseAll():
    ob.set_pressure(4, 80)
    sleep(3)
    ob.set_pressure(4,0)

# %%
ob.set_pressure(4, 1)
# Out:
# 0

# %%
ob.set_pressure(4, -118)
# Out:
# 0

# %%
ob.set_pressure(4,0)
# Out:
# 0

# %%
inThenHold()

# %%
dispenseAll()

# %%
def inThenOut():
    ob.set_pressure(4, -80)
    sleep(0.5)
    ob.set_pressure(4, 10)
    sleep(2)
    ob.set_pressure(4, 80)
    sleep(3)
    ob.set_pressure(4, 0)

# %%
inThenOut()

# %%
def stop():
    ob.set_pressure(4, 0)

# %%
stop()

# %%
ob.close()
print("DONE")
# Out:
# DONE
